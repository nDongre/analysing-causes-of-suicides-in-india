# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
data = pd.read_csv("Suicides in India 2001-2012.csv")

# %%
data.head()
# Out:
#            State  Year Type_code                                     Type  \
# 0  A & N Islands  2001    Causes                       Illness (Aids/STD)
# 1  A & N Islands  2001    Causes  Bankruptcy or Sudden change in Economic
# 2  A & N Islands  2001    Causes  Cancellation/Non-Settlement of Marriage
# 3  A & N Islands  2001    Causes        Physical Abuse (Rape/Incest Etc.)
# 4  A & N Islands  2001    Causes                            Dowry Dispute
#
#    Gender Age_group  Total
# 0  Female      0-14      0
# 1  Female      0-14      0
# 2  Female      0-14      0
# 3  Female      0-14      0
# 4  Female      0-14      0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237519 entries, 0 to 237518
# Data columns (total 7 columns):
# State        237519 non-null object
# Year         237519 non-null int64
# Type_code    237519 non-null object
# Type         237519 non-null object
# Gender       237519 non-null object
# Age_group    237519 non-null object
# Total        237519 non-null int64
# dtypes: int64(2), object(5)
# memory usage: 12.7+ MB

# %%
data.describe()
# Out:
#                 Year          Total
# count  237519.000000  237519.000000
# mean     2006.500448      55.034477
# std         3.452240     792.749038
# min      2001.000000       0.000000
# 25%      2004.000000       0.000000
# 50%      2007.000000       0.000000
# 75%      2010.000000       6.000000
# max      2012.000000   63343.000000

# %%
#From observing the head of data we realise that there are many '0' entries in the total column. That doesn't provide any significant insight.
data = data[data['Total'] != 0]

# %%
#New data
data.sample(20)
# Out:
#                     State  Year             Type_code  \
# 109743          Karnataka  2003  Professional_Profile
# 2621        A & N Islands  2005         Means_adopted
# 221611      Uttar Pradesh  2008  Professional_Profile
# 118708             Kerala  2007         Means_adopted
# 65982               Delhi  2010                Causes
# 19566   Arunachal Pradesh  2011  Professional_Profile
# 209051         Tamil Nadu  2012                Causes
# 44523        Chhattisgarh  2008                Causes
# 220411      Uttar Pradesh  2006         Means_adopted
# 109762          Karnataka  2003  Professional_Profile
# 66264               Delhi  2010  Professional_Profile
# 132258     Madhya Pradesh  2007  Professional_Profile
# 189355          Rajasthan  2001                Causes
# 206764         Tamil Nadu  2008                Causes
# 77705             Gujarat  2007                Causes
# 121715             Kerala  2012         Social_Status
# 31853               Bihar  2009         Means_adopted
# 133196     Madhya Pradesh  2009      Education_Status
# 223577      Uttar Pradesh  2012                Causes
# 115102             Kerala  2001                Causes
#
#                                            Type  Gender Age_group  Total
# 109743             Farming/Agriculture Activity  Female     15-29    119
# 2621                  By Consuming Insecticides  Female     45-59      3
# 221611             Farming/Agriculture Activity    Male      0-14      1
# 118708             By Self Infliction of injury  Female     45-59      1
# 65982                              Unemployment    Male     45-59      2
# 19566                      Service (Government)    Male     15-29      2
# 209051                                   Cancer    Male     30-44      4
# 44523                   Other Prolonged Illness  Female     15-29     77
# 220411  By coming under running vehicles/trains  Female     45-59      5
# 109762                  Others (Please Specify)  Female     30-44    202
# 66264                   Others (Please Specify)  Female     15-29     29
# 132258                               House Wife  Female     15-29   1128
# 189355                                  Poverty    Male     45-59      4
# 206764                   Illegitimate Pregnancy  Female     30-44      3
# 77705                Suspected/Illicit Relation  Female     15-29     24
# 121715                                 Divorcee  Female    0-100+     43
# 31853   By coming under running vehicles/trains    Male     15-29      1
# 133196                                 Graduate    Male    0-100+     71
# 223577                Fall in Social Reputation  Female     45-59     13
# 115102                Fall in Social Reputation  Female     45-59      4

# %%
#Data cleaning.

# %%
#Different entries for union territories
data.replace('A & N Islands (Ut)', 'A & N Islands', inplace=True)
data.replace('Chandigarh (Ut)', 'Chandigarh', inplace=True)
data.replace('D & N Haveli (Ut)', 'D & N Haveli', inplace=True)
data.replace('Daman & Diu (Ut)', 'Daman & Diu', inplace=True)
data.replace('Lakshadweep (Ut)', 'Lakshadweep', inplace=True)
data.replace('Delhi (Ut)', 'Delhi', inplace=True)

# %%
#Different label for same variable
data.replace('Bankruptcy or Sudden change in Economic', 
           'Bankruptcy or Sudden change in Economic Status', inplace=True)
data.replace('By Other means (please specify)', 'By Other means', inplace=True)
data.replace('Not having Children(Barrenness/Impotency',
           'Not having Children (Barrenness/Impotency', inplace=True)

# %%
#Value counts at the end of the document.
data = data.drop(data[(data.State == 'Total (Uts)') | (data.State == 'Total (All India)') | 
               (data.State == 'Total (States)')].index)

# %%
#Let us explore our data now

# %%
#Let us calculate different ratios in suicide counts
#Gender
gender = data.groupby('Gender').sum()['Total'].plot("bar", figsize=(5,4), title ="Gender wise suicides\n")
sns.set_style('whitegrid')

# %%
#Number of male suicides is significantly higher than female suicides.

# %%
age_group = data[data['Age_group']!='0-100+']

age = age_group.groupby('Age_group').sum()['Total'].plot("bar",figsize=(8,5), title ="Age wise suicides frequency");
sns.set_palette('Set2');

# %%
#Year wise
year = data.groupby(['State'])['Total'].sum().plot('bar', figsize=(20,10), title = 'Suicide rate per year');
sns.set_style('whitegrid');

# %%
year = data.groupby('Year').sum()['Total'].plot('line', figsize=(6,6), title = 'Suicide rate per year');
sns.set_style('whitegrid');

# %%
#Splitting dataset based on its type code

# %%
cause = data[data['Type_code'] == 'Causes']
edu_status = data[data['Type_code'] == 'Education_Status']
means_adpt = data[data['Type_code'] == 'Means_adopted']
prof = data[data['Type_code'] == 'Professional_Profile']
soc_status = data[data['Type_code'] == 'Social_Status']

# %%
#Grouping operations
def plot_type(df, Title, X_lab):
    p_type = df.groupby('Type').sum()['Total']
    sort_df = p_type.sort_values(ascending = False)

    fig = sort_df.plot('bar', figsize = (10,6), title = Title + '\n', width = 0.75)
    fig.set_xlabel('\n' + X_lab )
    fig.set_ylabel('Count\n')
    sns.set_style('whitegrid')
    sns.set_palette('Set2');

# %%
plot_type(cause, 'Suicide by cause', 'Cause')

# %%
plot_type(edu_status, 'Suicide by Education Status', 'Education Status')

# %%
plot_type(means_adpt, 'Suicide by Means Adopted', 'Means Adopted')

# %%
plot_type(prof, 'Suicide by Professional Profile', 'Professional Profile')

# %%
plot_type(soc_status, 'Suicide by Social Status', 'Social Status',)

# %%
age_lower = data[data['Age_group']== '0-14']
age_lower_cause = age_lower[age_lower['Type_code'] == 'Causes']
plot_type(age_lower_cause, 'Reason For Kids Suicide', 'Cause')

# %%
age_middle = data[data['Age_group']== '15-29']
age_middle_cause = age_middle[age_middle['Type_code'] == 'Causes']
plot_type(age_middle_cause, 'Reason For Kids Suicide', 'Cause')

# %%
age_late_middle = data[data['Age_group']== '30-44']
age_late_middle_cause = age_middle[age_middle['Type_code'] == 'Causes']
plot_type(age_middle_cause, 'Reason For Kids Suicide', 'Cause')

# %%
age_middle = data[data['Age_group']== '45-59']
age_middle_cause = age_middle[age_middle['Type_code'] == 'Causes']
plot_type(age_middle_cause, 'Reason For Kids Suicide', 'Cause')

# %%
age_middle = data[data['Age_group']== '60+']
age_middle_cause = age_middle[age_middle['Type_code'] == 'Causes']
plot_type(age_middle_cause, 'Reason For Kids Suicide', 'Cause')
